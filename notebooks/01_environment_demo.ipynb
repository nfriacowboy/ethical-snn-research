# %% [markdown]
# # Environment Demo - Ethical SNN Research
#
# This notebook demonstrates the grid world environment used in the ethical SNN research project.
#
# ## What you'll learn:
# - How to initialize and configure the grid world
# - Food spawning and resource management
# - Visualization of environment state
# - Collision detection and interaction mechanics
